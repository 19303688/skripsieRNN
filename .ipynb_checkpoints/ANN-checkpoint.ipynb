# %%
import sys

import tensorflow.keras
import pandas as pd
import sklearn as sk
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import platform
from sklearn.model_selection import train_test_split

print(f"Python Platform: {platform.platform()}")
print(f"Tensor Flow Version: {tf.__version__}")
print(f"Keras Version: {tensorflow.keras.__version__}")
print()
print(f"Python {sys.version}")
print(f"Pandas {pd.__version__}")
print(f"Scikit-Learn {sk.__version__}")
gpu = len(tf.config.list_physical_devices('GPU'))>0
print("GPU is", "available" if gpu else "NOT AVAILABLE")
# Out:
# Python Platform: macOS-13.2.1-arm64-arm-64bit
# Tensor Flow Version: 2.11.0
# Keras Version: 2.11.0
#
# Python 3.10.9 | packaged by conda-forge | (main, Feb  2 2023, 20:26:08) [Clang 14.0.6 ]
# Pandas 1.5.3
# Scikit-Learn 1.2.2
# GPU is available

# %%
#Load data and remove the entries where the plant is off.
df = pd.read_csv('data_cleaned.csv')
df.head()
# Out:
#    ECO SYS FW Supply SATN T  Economizer SYS FW Supply P  \
# 0                114.877136                    -0.03675
# 1                114.877136                    -0.03675
# 2                115.819984                    -0.03675
# 3                114.877136                    -0.03675
# 4                114.877136                    -0.03675
#
#    HP Steam Average Temp  Hot R/H Average Temp  Live Steam TOT F  ATT 1 m_dot  \
# 0              16.575009             16.602090          0.057947     0.008334
# 1              16.575009             16.629174          0.057947     0.008334
# 2              16.764593             16.629174          0.057947     0.008334
# 3              16.764593             16.656256          0.057947     0.008334
# 4              16.764593             16.602090          0.057947     0.008334
#
#    ATT 2 m_dot  R/H ATT m_dot  AMB Air T  Coal Input  ...  Unnamed: 65  \
# 0          0.0       0.012993  18.564453        0.04  ...          NaN
# 1          0.0       0.012993  18.022461        0.04  ...          NaN
# 2          0.0       0.012993  17.846680        0.04  ...          NaN
# 3          0.0       0.012993  17.587891        0.04  ...          NaN
# 4          0.0       0.012993  17.324219        0.04  ...          NaN
#
#    Unnamed: 66  Unnamed: 67  Unnamed: 68  Unnamed: 69  Unnamed: 70  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
#    Unnamed: 71  Unnamed: 72  Unnamed: 73  Unnamed: 74
# 0          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN
#
# [5 rows x 75 columns]

# %%
#Split data into the test
x_data = df[['ECO SYS FW Supply SATN T', 'Economizer SYS FW Supply P', 'Live Steam TOT F','AMB Air T','Coal Input',
             'BLR Primary Air F','BLR Secondary Air Total F','OVR FIR CORR Air NOZ 71-73 F','OVR FIR CORR Air NOZ 74-76 F',
             'OVR FIR CORR Air NOZ 81-83 F','OVR FIR CORR Air NOZ 84-86 F',]].values
y_data = df[['HP Steam Average Temp', 'Hot R/H Average Temp', 'ATT 1 m_dot', 'ATT 2 m_dot', 'R/H ATT m_dot']].values
x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.2, random_state=42)

# %%
class ANN(tf.keras.Model):
    def __init__(self, input_size, output_size):
        super(ANN, self).__init__()
        self.dense1 = layers.Dense(32, activation='relu')
        self.dense2 = layers.Dense(16, activation='relu')
        self.dense3 = layers.Dense(output_size, activation='softmax')
        
    def call(self, inputs):
        x = self.dense1(inputs)
        x = self.dense2(x)
        return self.dense3(x)

# Define the input and output sizes
input_size = 11
output_size = 5

# Create an instance of the custom model
model = ANN(input_size, output_size)

# Define the loss function and optimizer
loss_fn = tf.keras.losses.MeanSquaredError()
optimizer = tf.keras.optimizers.SGD(learning_rate=0.01)

# Compile the model
model.compile(optimizer=optimizer, loss=loss_fn)

# Train the model on your dataset
model.fit(x_train, y_train, epochs=10, batch_size=32)

# Evaluate the model on your test set
loss, accuracy = model.evaluate(x_test, y_test)
print(loss)
print(accuracy)
# Use the model to make predictions on new data
#y_pred = model.predict(x_new)
# Out:
# Epoch 1/10
# 2023-03-21 15:13:45.117839: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-21 15:13:45.432860: W tensorflow/core/framework/op_kernel.cc:1830] OP_REQUIRES failed at xla_ops.cc:418 : NOT_FOUND: could not find registered platform with id: 0x14a7c50e0
# 2023-03-21 15:13:45.432887: W tensorflow/core/framework/op_kernel.cc:1830] OP_REQUIRES failed at xla_ops.cc:418 : NOT_FOUND: could not find registered platform with id: 0x14a7c50e0
# 2023-03-21 15:13:45.436404: W tensorflow/core/framework/op_kernel.cc:1830] OP_REQUIRES failed at xla_ops.cc:418 : NOT_FOUND: could not find registered platform with id: 0x14a7c50e0
# 2023-03-21 15:13:45.436423: W tensorflow/core/framework/op_kernel.cc:1830] OP_REQUIRES failed at xla_ops.cc:418 : NOT_FOUND: could not find registered platform with id: 0x14a7c50e0
# 2023-03-21 15:13:45.440018: W tensorflow/core/framework/op_kernel.cc:1830] OP_REQUIRES failed at xla_ops.cc:418 : NOT_FOUND: could not find registered platform with id: 0x14a7c50e0
# 2023-03-21 15:13:45.440041: W tensorflow/core/framework/op_kernel.cc:1830] OP_REQUIRES failed at xla_ops.cc:418 : NOT_FOUND: could not find registered platform with id: 0x14a7c50e0
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[41], line 28
#      25 model.compile(optimizer=optimizer, loss=loss_fn)
#      27 # Train the model on your dataset
# ---> 28 model.fit(x_train, y_train, epochs=10, batch_size=32)
#      30 # Evaluate the model on your test set
#      31 loss, accuracy = model.evaluate(x_test, y_test)
#
# File ~/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~/miniconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/eager/execute.py:52, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50 try:
#      51   ctx.ensure_initialized()
# ---> 52   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                       inputs, attrs, num_outputs)
#      54 except core._NotOkStatusException as e:
#      55   if name is not None:
#
# NotFoundError: Graph execution error:
#
# Detected at node 'StatefulPartitionedCall_4' defined at (most recent call last):
#     File "/Users/calvindurr/miniconda3/envs/tensorflow/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#       return _run_code(code, main_globals, None,
#     File "/Users/calvindurr/miniconda3/envs/tensorflow/lib/python3.10/runpy.py", line 86, in _run_code
#       exec(code, run_globals)
#     File "/Users/calvindurr/miniconda3/envs/tensorflow/lib/python3.10/site-packages/ipykernel_launcher.py", line 17, in <module>
#       app.launch_new_instance()
#     File "/Users/calvindurr/miniconda3/envs/tensorflow/lib/python3.10/site-packages/traitlets/config/application.py", line 1043, in launch_instance
#       app.start()
#     File "/Users/calvindurr/miniconda3/envs/tensorflow/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 725, in start
#       self.io_loop.start()
#     File "/Users/calvindurr/miniconda3/envs/tensorflow/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 215, in start
#       self.asyncio_loop.run_forever()
#     File "/Users/calvindurr/miniconda3/envs/tensorflow/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#       self._run_once()
#     File "/Users/calvindurr/miniconda3/envs/tensorflow/lib/python3.10/asyncio/base_events.py", line 1906, in _run_once
#       handle._run()
#     File "/Users/calvindurr/miniconda3/envs/tensorflow/lib/python3.10/asyncio/events.py", line 80, in _run
#       self._context.run(self._callback, *self._args)
#     File "/Users/calvindurr/miniconda3/envs/tensorflow/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 513, in dispatch_queue
#       await self.process_one()
#     File "/Users/calvindurr/miniconda3/envs/tensorflow/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 502, in process_one
#       await dispatch(*args)
#     File "/Users/calvindurr/miniconda3/envs/tensorflow/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 409, in dispatch_shell
#       await result
#     File "/Users/calvindurr/miniconda3/envs/tensorflow/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 729, in execute_request
#       reply_content = await reply_content
#     File "/Users/calvindurr/miniconda3/envs/tensorflow/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 422, in do_execute
#       res = shell.run_cell(
#     File "/Users/calvindurr/miniconda3/envs/tensorflow/lib/python3.10/site-packages/ipykernel/zmqshell.py", line 540, in run_cell
#       return super().run_cell(*args, **kwargs)
#     File "/Users/calvindurr/miniconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 2961, in run_cell
#       result = self._run_cell(
#     File "/Users/calvindurr/miniconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3016, in _run_cell
#       result = runner(coro)
#     File "/Users/calvindurr/miniconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#       coro.send(None)
#     File "/Users/calvindurr/miniconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3221, in run_cell_async
#       has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     File "/Users/calvindurr/miniconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3400, in run_ast_nodes
#       if await self.run_code(code, result, async_=asy):
#     File "/Users/calvindurr/miniconda3/envs/tensorflow/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3460, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "/var/folders/nc/qvnyyrpd0bs8ck8vt79yvt080000gn/T/ipykernel_14159/1036191479.py", line 28, in <module>
#       model.fit(x_train, y_train, epochs=10, batch_size=32)
#     File "/Users/calvindurr/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/utils/traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "/Users/calvindurr/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/engine/training.py", line 1650, in fit
#       tmp_logs = self.train_function(iterator)
#     File "/Users/calvindurr/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/engine/training.py", line 1249, in train_function
#       return step_function(self, iterator)
#     File "/Users/calvindurr/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/engine/training.py", line 1233, in step_function
#       outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/Users/calvindurr/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/engine/training.py", line 1222, in run_step
#       outputs = model.train_step(data)
#     File "/Users/calvindurr/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/engine/training.py", line 1027, in train_step
#       self.optimizer.minimize(loss, self.trainable_variables, tape=tape)
#     File "/Users/calvindurr/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/optimizers/optimizer_experimental/optimizer.py", line 527, in minimize
#       self.apply_gradients(grads_and_vars)
#     File "/Users/calvindurr/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/optimizers/optimizer_experimental/optimizer.py", line 1140, in apply_gradients
#       return super().apply_gradients(grads_and_vars, name=name)
#     File "/Users/calvindurr/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/optimizers/optimizer_experimental/optimizer.py", line 634, in apply_gradients
#       iteration = self._internal_apply_gradients(grads_and_vars)
#     File "/Users/calvindurr/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/optimizers/optimizer_experimental/optimizer.py", line 1166, in _internal_apply_gradients
#       return tf.__internal__.distribute.interim.maybe_merge_call(
#     File "/Users/calvindurr/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/optimizers/optimizer_experimental/optimizer.py", line 1216, in _distributed_apply_gradients_fn
#       distribution.extended.update(
#     File "/Users/calvindurr/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/optimizers/optimizer_experimental/optimizer.py", line 1211, in apply_grad_to_update_var
#       return self._update_step_xla(grad, var, id(self._var_key(var)))
# Node: 'StatefulPartitionedCall_4'
# could not find registered platform with id: 0x14a7c50e0
# 	 [[{{node StatefulPartitionedCall_4}}]] [Op:__inference_train_function_1506]
